# %%
general_code_dataset_languages = ['python', 'javascript', 'c', 'cpp', 'java', 'go', 'php', 'ruby', 'rust']
cybernative_dpo_dataset_languages = ['python', 'java', 'javascript', 'php', 'ruby', 'go']

all_languages = list(set(general_code_dataset_languages) | set(cybernative_dpo_dataset_languages))
print("Total number of unique programming languages:", len(all_languages))
print(all_languages)
# Out:
# Total number of unique programming languages: 9
# ['go', 'java', 'ruby', 'php', 'c', 'python', 'rust', 'cpp', 'javascript']

# %%
len(general_code_dataset_languages)
# Out:
# 9
